# %% [markdown]
# # Example using matplotlib and ipympl for interactive plotting

# %%
# %matplotlib ipympl

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
cs = ax.contourf([[1,2],[3,5]])
fig.colorbar(cs, ax=ax);
